# %% [markdown]
# ## Dataset and Problem Selection
#
# I chose to try to implement a many-to-many model of an RNN to translate from English to German. I found a dataset that was used in the Fifth Confrence on Machine Translation (WMT20 https://www.statmt.org/wmt20/translation-task.html) which was used to help translate news articles in a variety of languages. I used the TILDE Model - RAPID corpus for English to German found here: https://tilde-model.s3-eu-west-1.amazonaws.com/Tilde_MODEL_Corpus.html.
#
# The data was in a format commonly used in machine translation called TMX, an XML-like format that contains pairs of sentences in both languages. I used the python library translate-toolkit to read in the file.

# %%
from translate.storage.tmx import tmxfile

with open("RAPID_2019.UNIQUE.de-en.tmx", 'rb') as file:
    tmx_file = tmxfile(file, 'en', 'ar')

# %% [markdown]
# ### Dataset Preprocessing

# %%
import re
X, Y = [], []

for node in tmx_file.unit_iter():
    X.append(re.sub(r'[^A-Za-z\s]', '', node.source).lower().split())
    Y.append(re.sub(r'[^A-Za-z\s]', '', node.target).lower().split())

xd, yd = X[0:20000], Y[0:20000]

# %%
for i in range(len(xd)):
    xd[i] = np.array(xd[i]).reshape((len(xd[i]), 1))
    

print(xd[0: 100])
# Out:
# ['abf', 'tibetische', 'pressefreiheit', 'bel', 'ehrlicher', 'bewerbern', 'wirkungsvollen', 'ffentlichen', 'partizipative', 'lnderspezifischer', 'holdings', 'getrnke', 'drain', 'monaten', 'personenverkehrs', 'invitrodiagnose', 'strukturen', 'prostitution', 'health', 'philippe', 'vogelgebiete', 'ticonawerk', 'verschlechterte', 'kontrollniveaus', 'erweiterungsrunden', 'investitionsplne', 'fuehrte', 'defizite', 'ackerlandes', 'nachteile', 'israelis', 'kunstwerke', 'italienische', 'einvernehmliche', 'abschreckungswirkung', 'beratenden', 'manuell', 'verzinsen', 'grundnahrungsmittel', 'gteborg', 'sehen', 'finanzexperten', 'verkehrsdiensten', 'abschlusszahlungen', 'magebliche', 'beifall', 'festlandssockel', 'forschungsagenda', 'trust', 'gremiums', 'zielgesellschaft', 'erkenntnissen', 'byrne', 'regeln', 'geschwindigkeiten', 'funktionieren', 'rechtswesens', 'gesamthandelsbilanz', 'geldbue', 'wettbewerbsfrderung', 'verwundert', 'fangflotte', 'internationalisierung', 'widerrufen', 'inflationsdru
# ...

# %%
import tensorflow as tf
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import LabelEncoder

l_enc = LabelEncoder()
int_enc = l_enc.fit_transform(list(set(np.concatenate(xd).flat)))
#int_enc = l_enc.transform(xd[0])
#print(int_enc)
# x = list(set(np.concatenate(xd).flat))
# print(len(x))

enc = OneHotEncoder(handle_unknown='ignore')
enc.fit(int_enc.reshape(len(int_enc), 1))
xd_h = enc.transform(xd[0])

#xd = tf.convert_to_tensor(xd)
#yd = tf.convert_to_tensor(yd)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.local/lib/python3.8/site-packages/sklearn/utils/_encode.py in _encode(values, uniques, check_unknown)
#     177         try:
# --> 178             return _map_to_integer(values, uniques)
#     179         except KeyError as e:
#
# ~/.local/lib/python3.8/site-packages/sklearn/utils/_encode.py in _map_to_integer(values, uniques)
#     122     table = _nandict({val: i for i, val in enumerate(uniques)})
# --> 123     return np.array([table[v] for v in values])
#     124
#
# ~/.local/lib/python3.8/site-packages/sklearn/utils/_encode.py in <listcomp>(.0)
#     122     table = _nandict({val: i for i, val in enumerate(uniques)})
# --> 123     return np.array([table[v] for v in values])
#     124
#
# ~/.local/lib/python3.8/site-packages/sklearn/utils/_encode.py in __missing__(self, key)
#     116             return self.nan_value
# ...

# %% [markdown]
# I chose to use the Tensorflow library, since I am already familiar with it, and Tensorflow Keras has a good package for working with RNNs
#
# ## Implementation

# %%
from tensorflow import keras
from tensorflow.keras import layers

# %%
model = keras.Sequential()
model.add(layers.Embedding(input_dim=1000, output_dim=64))
model.add(layers.SimpleRNN(128))
model.add(layers.Dense(10))
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# embedding_1 (Embedding)      (None, None, 64)          64000
# _________________________________________________________________
# simple_rnn_1 (SimpleRNN)     (None, 128)               24704
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                1290
# ...
# Total params: 89,994
# Trainable params: 89,994
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer="adam", loss="mse", metrics=["accuracy"])
model.fit(xd, yd)
# Out:
# /home/crottm/.local/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-b8ea89f81025> in <module>
#       1 model.compile(optimizer="adam", loss="mse", metrics=["accuracy"])
# ----> 2 model.fit(xd, yd)
#
# ...
